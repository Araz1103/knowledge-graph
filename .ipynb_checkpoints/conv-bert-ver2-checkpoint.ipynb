# %% [markdown]
# ## Building a Tiny Knowledge Graph with BERT and Graph Convolutions
# This notebook is the source of the code to build and test the graph described in the article

# %%
import argparse
import io
import json
import os

from google.cloud import language
import numpy
import six
import numpy as np
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# The following is a simple function for cleaning and extracting sentences.   it was pulled from the web.  not sure of provenance.

# %%
# -*- coding: utf-8 -*-
import re
alphabets= "([A-Za-z])"
prefixes = "(Mr|St|Mrs|Ms|Dr)[.]"
suffixes = "(Inc|Ltd|Jr|Sr|Co)"
starters = "(Mr|Mrs|Ms|Dr|He\s|She\s|It\s|They\s|Their\s|Our\s|We\s|But\s|However\s|That\s|This\s|Wherever)"
acronyms = "([A-Z][.][A-Z][.](?:[A-Z][.])?)"
websites = "[.](com|net|org|io|gov)"

def split_into_sentences(text):
    text = " " + text + "  "
    text = text.replace("\n"," ")
    text = re.sub(prefixes,"\\1<prd>",text)
    text = re.sub(websites,"<prd>\\1",text)
    if "Ph.D" in text: text = text.replace("Ph.D.","Ph<prd>D<prd>")
    text = re.sub("\s" + alphabets + "[.] "," \\1<prd> ",text)
    text = re.sub(acronyms+" "+starters,"\\1<stop> \\2",text)
    text = re.sub(alphabets + "[.]" + alphabets + "[.]" + alphabets + "[.]","\\1<prd>\\2<prd>\\3<prd>",text)
    text = re.sub(alphabets + "[.]" + alphabets + "[.]","\\1<prd>\\2<prd>",text)
    text = re.sub(" "+suffixes+"[.] "+starters," \\1<stop> \\2",text)
    text = re.sub(" "+suffixes+"[.]"," \\1<prd>",text)
    text = re.sub(" " + alphabets + "[.]"," \\1<prd>",text)
    if "”" in text: text = text.replace(".”","”.")
    if "\"" in text: text = text.replace(".\"","\".")
    if "!" in text: text = text.replace("!\"","\"!")
    if "?" in text: text = text.replace("?\"","\"?")
    text = text.replace(".",".<stop>")
    text = text.replace("?","?<stop>")
    text = text.replace("!","!<stop>")
    text = text.replace("<prd>",".")
    sentences = text.split("<stop>")
    sentences = sentences[:-1]
    sentences = [s.strip() for s in sentences]
    return sentences

# %% [markdown]
# # invoking the google entity extractor
# to use it you must set up a google cloud account and sign up for the language.googleapis.com service.  You will also need your google credential set  up correctly.  in writing the article and debugging this notebook,  i have spent $26.   so if you have a free google cloud account it won't cost much.

# %%
from google.cloud import language_v1
from google.oauth2 import service_account

creds = service_account.Credentials.from_service_account_file('key.json')
language_client = language_v1.LanguageServiceClient(credentials=creds,)

def classify(text, verbose=True):
    """Classify the input text into categories. """
    document = language_v1.Document(content=text, type_=language_v1.Document.Type.PLAIN_TEXT)
    encoding_type = language_v1.EncodingType.UTF8
    response = language_client.analyze_entities(document = document,encoding_type = encoding_type)
    return response

import requests
import wikipedia
def findWikiData(itemurl):
    st = itemurl.find('wiki/')
    item = itemurl[st+5:]
    #print(item)
    s= "https://en.wikipedia.org/w/api.php?action=query&prop=pageprops&titles=%s&format=json"%(item)
    r = requests.get(s)
    rr =r.content.decode("utf-8")
    #print('rr=', rr)
    ans = rr.find('wikibase_item')
    answer = rr[ans+16:]
    e = answer.find('"')
    return item, answer[:e]

# %% [markdown]
# This function grabs the instanceOf data (P31) from wikidata.  it returns an empty string if it fails to find anything.  it is basically scraping the json to find the information.  not very elegant.

# %%
def getInstanceOfId(wikiID):
    s = 'https://www.wikidata.org/w/api.php?action=wbgetentities&ids=%s&languages=en&format=json'%(wikiID)
    r = requests.get(s)
    rr =r.content.decode("utf-8")
    try:
        j = json.loads(rr)
        k = rr.find('P31')
        if k > 0:
            l = rr[k:].find('"id":')
            if l > 0:
                s = rr[k+l+5:k+l+23]
                t = s.find('}')
                id = s[1:t-1]
                x = id.find('$')
                if x < 0:
                    return id
                else:
                    return id[:x]
            else:
                return ''
        else:
            return ''
    except:
        return ''

# %%
getInstanceOfId('Q678023')

# %% [markdown]
# This is another wikidata scrape to find the name of an object given it's wikidataID

# %%
def getNameFromWikiID(wikiID):
    s = 'https://www.wikidata.org/w/api.php?action=wbgetentities&ids=%s&languages=en&format=json'%(wikiID)
    r = requests.get(s)
    if r.status_code == 429:
        time.sleep(8)
        r = requests.get(s)
    rr = r.content.decode("utf-8")
    s = rr.find('"value":')
    rrr= rr[s+8:s+50]
    t = rrr.find('}')
    return rrr[1:t-1]

# %%
getNameFromWikiID("Q55814")
# Out:
# 'extinction event'

# %%
def getDescription(wikiId):
    s = 'https://www.wikidata.org/w/api.php?action=wbgetentities&ids=%s&languages=en&format=json'%(wikiId)
    r = requests.get(s)
    if r.status_code == 429:
      time.sleep(8)
      r = requests.get(s)

    rr =r.content.decode("utf-8")
    i = rr.find("descriptions")
    if i < 0:
        return ''
    else:
        rrr = rr[i:]
        #print(rrr)
        j = rrr.find('"value":')
        if j >0:
            #print(j)
            k = rrr.find("}")
            return(rrr[j+8: k])
        else:
            return ''

# %%
getDescription("Q55814")

# %% [markdown]
# This function extracts entities from a sentence.   if it is a wikipedia entity  it pulls some wikidata.

# %%
def entityExtractorBlock(sents):
    ents = []
    x = classify(sents)
    for ent in x.entities:
        print('--->', ent.name)
        print(ent)
        if ent.metadata['wikipedia_url'] != '' or len(str.split(ent.name))> 1:
            wikipage = ent.metadata['wikipedia_url']
            if wikipage != '':
                name, wikidataId = findWikiData(wikipage)
                ents.append((name, wikidataId, wikipage))

            else:
                wikidataId = "none"
                #print(name, wikidataId, wikipage)
                ents.append((ent.name, wikidataId, wikipage))
        elif(not ent.name.lower() in STOP_WORDS and not ent.name.lower()[:-1] in STOP_WORDS):
            ents.append((ent.name, "none", ''))
        
    return ents

# %%
import networkx as nx

# %% [markdown]
# The entity extractor creates a list that consists of a list of all of the entities and the last item in the list is the sentence.

# %%
def entityExtractor(sent):
    ents = []
    newents = entityExtractorBlock(sent)
    if newents != []:
        entitem = []
        for x in newents:
            entitem.append({'entity': x})
        entitem.append({'context': sent})
        ents = ents + entitem
    #print(entitem)
    return ents

# %%
def get_ents(sent):
    doc = nlp(sent)
    parts_of_speech = ["NOUN", "PROPN"] #Categories of Keywords/Phrases to consider as entities
    ents = []
    at_least_1 = 0
    for token in doc:
        if token.pos_ in parts_of_speech and token.is_stop is False and token.is_punct is False:
            at_least_1 = 1
            ents.append((token.lemma_,'none', ''))
    if(not at_least_1):
        ents.append(('none', 'none', ''))
    return ents

# %%
def get_nouns(sent):
    doc = nlp(sent)
    parts_of_speech = ["NOUN", "PROPN"] #Categories of Keywords/Phrases to consider as entities
    ents = []
    at_least_1 = 0
    for token in doc:
        if token.pos_ in parts_of_speech and token.is_stop is False and token.is_punct is False:
            at_least_1 = 1
            ents.append({'entity': (token.lemma_,'none', '')})
    if(not at_least_1):
        ents.append({'entity': ('none', 'none', '')})
    ents.append({'context': sent})
    return ents

# %% [markdown]
# ## add a new file to the graph.
# because the articles are named as ArtN to add a new article you need to know the number of articles currently in the graph.  that is art_cnt.
#
# for each sentence in the article it invokes the entity extractor.  with the list of entities it creates the entity nodes for each.   for those entities that are in wikipedia it create a list of "instanceOf" entities (lightgray in color).  it finally creates an article node.   When this is all done it adds the edges as needed.

# %%
def addFile(art_cnt, G, filename):
    items = open(filename+'.txt', 'r').read()
    print(items)
    sents = items.split("\n")
    print(sents)
    #split_into_sentences(items)
    for sent in sents:
        print(sent)
        ents = entityExtractor(sent)
        print("Entities:")
        print(ents)
        if(ents == []):
            ents = get_nouns(sent)
            print("New:",ents)
        all_nodes = []
        nodes = []
        instances = []
        ent_list = []
        for e in ents:
            if e.get('entity') != None:
                ent_list.append(e['entity'][0])
                #this is an entity for this node
                lab = e['entity'][2]
                name = e['entity'][0]
                wikiID = e['entity'][1]
                st = lab.find('wiki/')
                if st <0: #Is a noun phrase
                    item = name
                    #print('Item=', item)
                    G.add_node(item, flavor='entity', url='none', wikiID = 'noID', color = 'lightgreen')
                    #print("just made ", G.node[item])
                    G.nodes[item]['instanceof'] = []
                    G.nodes[item]['subclassof'] = []
                    G.nodes[item]['description'] = ''
                    nodes.append(item)

                else:
                    item = lab[st+5:]
                    #print("item=", item)
                    #wikiID = findWikiData(lab)[1]
                    G.add_node(item, flavor='entity', url=lab, wikiID = wikiID, color = 'lightblue') #wikipedia
                    #print("just smade ", item, G.nodes[item])
                    instID = getInstanceOfId(wikiID)
                    if instID != '':
                        inst_list = [(instID, getNameFromWikiID(instID))]
                        #print([wikiID, (instID, getNameFromWikiID(instID))])
                    else:
                        inst_list = []
                    clas_list = []#isASubclassOf(wikiID)
                    G.nodes[item]['instanceof'] = inst_list
                    instances = instances + inst_list
                    G.nodes[item]['subclassof'] = clas_list        
                    #classes = classes + clas_list
                    G.nodes[item]['description'] = getDescription(wikiID)
                    #print(findWikiData(lab))
                    nodes.append(item)
            if e.get('context') != None:
                # this is a new article
                newart = 'Art'+str(art_cnt)
                G.add_node(newart, flavor='article', source=filename, context=e['context'], color='lightyellow')
                G.nodes[newart]['ent-list'] = ent_list
                #print(newart,G.nodes[newart])
                art_cnt = art_cnt+1
                for z in nodes:
                    G.add_edge(newart,z )
                all_nodes = all_nodes + nodes
                nodes = []
        instance_set = set(instances)
        instances = list(instance_set)
        if instances != []:
            print('instances ====', instances)
        #now make items for these instances
        for i in instances:
            G.add_node(i[1], flavor='entity', url='notknown', wikiID = i[0], color = 'lightgray')
            G.nodes[i[1]]['description'] = getDescription(i[0])
            G.nodes[i[1]]['instanceof'] = []
            G.nodes[i[1]]['subclassof'] = []
        #now add edges from the instance to the new entity
        all_nodes_set = set(all_nodes)
        all_nodes =  list(all_nodes_set)
        for n in all_nodes:
            if G.nodes[n]['instanceof'] != []:
                elist = G.nodes[n]['instanceof']
                for e in elist:
                    G.add_edge(n, e[1])
    print(art_cnt)
    return art_cnt

# %% [markdown]
# ## Importing Data

# %%
f = open("Paragraphs.json","r",encoding="utf8")
Paragraphs = json.load(f)
print(len(Paragraphs))
# Out:
# 456

# %%
Para_Num = int(input("Enter the Paragraph number you want "))
# Out:
# Enter the Paragraph number you want1

# %%
for sent in range(len(Paragraphs[Para_Num])):
    name = "Data/Para" + str(Para_Num) + "Sent" + str(sent+1) +".txt"
    test_f = open(name,"w+")
    test_f.write(Paragraphs[Para_Num][sent])
    test_f.close()

# %%
f = open("Questions.json","r",encoding="utf8")
data_qs = json.load(f)
print(len(data_qs))
# Out:
# 456

# %%
Questions = data_qs[Para_Num]
Num_of_Qs = len(Questions)

# %%
f = open("Answers.json","r",encoding="utf8")
answer_qs = json.load(f)
print(len(answer_qs))
# Out:
# 456

# %%
Answer_Para = answer_qs[Para_Num]

# %% [markdown]
# ## Building our Graph

# %%
G = nx.Graph()
art_cnt = 0
for sent in range(len(Paragraphs[Para_Num])):
    name = "Data/Para" + str(Para_Num) + "Sent" + str(sent+1)
    art_cnt = addFile(art_cnt, G, name)
graph_name = "Para" + str(Para_Num)
nx.write_gpickle(G, graph_name)
G = nx.read_gpickle(graph_name)
# Out:
# Before the mysterious disappearance of one of its passenger jets this month, Malaysia wasn't a country used to finding itself dominating headlines around the world.
# ["Before the mysterious disappearance of one of its passenger jets this month, Malaysia wasn't a country used to finding itself dominating headlines around the world."]
# Before the mysterious disappearance of one of its passenger jets this month, Malaysia wasn't a country used to finding itself dominating headlines around the world.
# ---> Malaysia
# name: "Malaysia"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/09pmkv"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Malaysia"
# }
# salience: 0.3436006
# mentions {
#   text {
#     content: "Malaysia"
#     begin_offset: 77
#   }
#   type_: PROPER
# }
#
# ---> disappearance
# name: "disappearance"
# type_: EVENT
# salience: 0.27751133
# mentions {
#   text {
#     content: "disappearance"
#     begin_offset: 22
#   }
#   type_: COMMON
# }
#
# ---> one
# name: "one"
# type_: OTHER
# salience: 0.117420994
# mentions {
#   text {
#     content: "one"
#     begin_offset: 39
#   }
#   type_: COMMON
# }
#
# ---> country
# name: "country"
# type_: LOCATION
# salience: 0.08204345
# mentions {
#   text {
#     content: "country"
#     begin_offset: 95
#   }
#   type_: COMMON
# }
#
# ---> passenger jets
# name: "passenger jets"
# type_: OTHER
# salience: 0.081089444
# mentions {
#   text {
#     content: "passenger jets"
#     begin_offset: 50
#   }
#   type_: COMMON
# }
#
# ---> headlines
# name: "headlines"
# type_: OTHER
# salience: 0.05760001
# mentions {
#   text {
#     content: "headlines"
#     begin_offset: 137
#   }
#   type_: COMMON
# }
#
# ---> world
# name: "world"
# type_: LOCATION
# salience: 0.040734176
# mentions {
#   text {
#     content: "world"
#     begin_offset: 158
#   }
#   type_: COMMON
# }
#
# ---> one
# name: "one"
# type_: NUMBER
# metadata {
#   key: "value"
#   value: "1"
# }
# mentions {
#   text {
#     content: "one"
#     begin_offset: 39
#   }
# }
#
# Entities:
# [{'entity': ('Malaysia', 'Q833', 'https://en.wikipedia.org/wiki/Malaysia')}, {'entity': ('disappearance', 'none', '')}, {'entity': ('country', 'none', '')}, {'entity': ('passenger jets', 'none', '')}, {'entity': ('headlines', 'none', '')}, {'entity': ('world', 'none', '')}, {'context': "Before the mysterious disappearance of one of its passenger jets this month, Malaysia wasn't a country used to finding itself dominating headlines around the world."}]
# instances ==== [('Q3624078', 'sovereign state')]
# 1
# Some of its Southeast Asian neighbors, including Indonesia and the Philippines, have suffered devastating natural disasters in recent years and are all too familiar with the media frenzy that accompanies a major crisis.
# ['Some of its Southeast Asian neighbors, including Indonesia and the Philippines, have suffered devastating natural disasters in recent years and are all too familiar with the media frenzy that accompanies a major crisis.']
# Some of its Southeast Asian neighbors, including Indonesia and the Philippines, have suffered devastating natural disasters in recent years and are all too familiar with the media frenzy that accompanies a major crisis.
# ---> Some
# name: "Some"
# type_: PERSON
# salience: 0.37980565
# mentions {
#   text {
#     content: "Some"
#   }
#   type_: COMMON
# }
#
# ---> Southeast Asian
# name: "Southeast Asian"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/073q1"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Southeast_Asia"
# }
# salience: 0.18084247
# mentions {
#   text {
#     content: "Southeast Asian"
#     begin_offset: 12
#   }
#   type_: PROPER
# }
#
# ---> neighbors
# name: "neighbors"
# type_: PERSON
# salience: 0.119984575
# mentions {
#   text {
#     content: "neighbors"
#     begin_offset: 28
#   }
#   type_: COMMON
# }
#
# ---> media frenzy
# name: "media frenzy"
# type_: OTHER
# salience: 0.095366694
# mentions {
#   text {
#     content: "media frenzy"
#     begin_offset: 174
#   }
#   type_: COMMON
# }
#
# ---> disasters
# name: "disasters"
# type_: EVENT
# salience: 0.08364959
# mentions {
#   text {
#     content: "disasters"
#     begin_offset: 114
#   }
#   type_: COMMON
# }
#
# ---> Philippines
# name: "Philippines"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/05v8c"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Philippines"
# }
# salience: 0.049759444
# mentions {
#   text {
#     content: "Philippines"
#     begin_offset: 67
#   }
#   type_: PROPER
# }
#
# ---> Indonesia
# name: "Indonesia"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/03ryn"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Indonesia"
# }
# salience: 0.04916671
# mentions {
#   text {
#     content: "Indonesia"
#     begin_offset: 49
#   }
#   type_: PROPER
# }
#
# ---> crisis
# name: "crisis"
# type_: EVENT
# salience: 0.04142485
# mentions {
#   text {
#     content: "crisis"
#     begin_offset: 212
#   }
#   type_: COMMON
# }
#
# Entities:
# [{'entity': ('Southeast_Asia', 'Q11708', 'https://en.wikipedia.org/wiki/Southeast_Asia')}, {'entity': ('neighbors', 'none', '')}, {'entity': ('media frenzy', 'none', '')}, {'entity': ('disasters', 'none', '')}, {'entity': ('Philippines', 'Q928', 'https://en.wikipedia.org/wiki/Philippines')}, {'entity': ('Indonesia', 'Q252', 'https://en.wikipedia.org/wiki/Indonesia')}, {'entity': ('crisis', 'none', '')}, {'context': 'Some of its Southeast Asian neighbors, including Indonesia and the Philippines, have suffered devastating natural disasters in recent years and are all too familiar with the media frenzy that accompanies a major crisis.'}]
# instances ==== [('Q928', 'Philippines'), ('Q3624078', 'sovereign state'), ('Q82794', 'geographic region')]
# 2
# But Malaysia has largely managed to stay out of the international spotlight since its independence from British colonial rule more than half a century ago.
# ['But Malaysia has largely managed to stay out of the international spotlight since its independence from British colonial rule more than half a century ago.']
# But Malaysia has largely managed to stay out of the international spotlight since its independence from British colonial rule more than half a century ago.
# ---> Malaysia
# name: "Malaysia"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/09pmkv"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Malaysia"
# }
# salience: 0.6491518
# mentions {
#   text {
#     content: "Malaysia"
#     begin_offset: 4
#   }
#   type_: PROPER
# }
#
# ---> spotlight
# name: "spotlight"
# type_: OTHER
# salience: 0.12517129
# mentions {
#   text {
#     content: "spotlight"
#     begin_offset: 66
#   }
#   type_: COMMON
# }
#
# ---> independence
# name: "independence"
# type_: EVENT
# salience: 0.115533024
# mentions {
#   text {
#     content: "independence"
#     begin_offset: 86
#   }
#   type_: COMMON
# }
#
# ---> British
# name: "British"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/07ssc"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/United_Kingdom"
# }
# salience: 0.07019829
# mentions {
#   text {
#     content: "British"
#     begin_offset: 104
#   }
#   type_: PROPER
# }
#
# ---> rule
# name: "rule"
# type_: OTHER
# salience: 0.039945625
# mentions {
#   text {
#     content: "rule"
#     begin_offset: 121
#   }
#   type_: COMMON
# }
#
# Entities:
# [{'entity': ('Malaysia', 'Q833', 'https://en.wikipedia.org/wiki/Malaysia')}, {'entity': ('spotlight', 'none', '')}, {'entity': ('independence', 'none', '')}, {'entity': ('United_Kingdom', 'Q145', 'https://en.wikipedia.org/wiki/United_Kingdom')}, {'entity': ('rule', 'none', '')}, {'context': 'But Malaysia has largely managed to stay out of the international spotlight since its independence from British colonial rule more than half a century ago.'}]
# instances ==== [('Q13341593', 'permanent member'), ('Q3624078', 'sovereign state')]
# 3
# "It is one of these countries, because of its geography, that doesn't have earthquakes," said Ernest Bower, senior adviser for Southeast Asia studies at the Center for Strategic and International Studies.
# ['"It is one of these countries, because of its geography, that doesn\'t have earthquakes," said Ernest Bower, senior adviser for Southeast Asia studies at the Center for Strategic and International Studies.']
# "It is one of these countries, because of its geography, that doesn't have earthquakes," said Ernest Bower, senior adviser for Southeast Asia studies at the Center for Strategic and International Studies.
# ---> one
# name: "one"
# type_: OTHER
# salience: 0.5404993
# mentions {
#   text {
#     content: "one"
#     begin_offset: 7
#   }
#   type_: COMMON
# }
#
# ---> Ernest Bower
# name: "Ernest Bower"
# type_: PERSON
# metadata {
#   key: "mid"
#   value: "/g/113r3rbrk"
# }
# salience: 0.11559381
# mentions {
#   text {
#     content: "Ernest Bower"
#     begin_offset: 94
#   }
#   type_: PROPER
# }
# mentions {
#   text {
#     content: "senior adviser"
#     begin_offset: 108
#   }
#   type_: COMMON
# }
#
# ---> countries
# name: "countries"
# type_: LOCATION
# salience: 0.11322105
# mentions {
#   text {
#     content: "countries"
#     begin_offset: 20
#   }
#   type_: COMMON
# }
#
# ---> earthquakes
# name: "earthquakes"
# type_: EVENT
# salience: 0.07773947
# mentions {
#   text {
#     content: "earthquakes"
#     begin_offset: 75
#   }
#   type_: COMMON
# }
#
# ---> geography
# name: "geography"
# type_: OTHER
# salience: 0.07773947
# mentions {
#   text {
#     content: "geography"
#     begin_offset: 46
#   }
#   type_: COMMON
# }
#
# ---> Center for Strategic and International Studies
# name: "Center for Strategic and International Studies"
# type_: ORGANIZATION
# metadata {
#   key: "mid"
#   value: "/m/02n4mz"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Center_for_Strategic_and_International_Studies"
# }
# salience: 0.032860085
# mentions {
#   text {
#     content: "Center for Strategic and International Studies"
#     begin_offset: 157
#   }
#   type_: PROPER
# }
# ---> studies
# name: "studies"
# type_: OTHER
# salience: 0.027819652
# mentions {
#   text {
#     content: "studies"
#     begin_offset: 142
#   }
#   type_: COMMON
# }
#
# ---> Southeast Asia
# name: "Southeast Asia"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/073q1"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Southeast_Asia"
# }
# salience: 0.014527106
# mentions {
#   text {
#     content: "Southeast Asia"
#     begin_offset: 127
#   }
#   type_: PROPER
# }
#
# ---> one
# name: "one"
# type_: NUMBER
# metadata {
#   key: "value"
#   value: "1"
# }
# mentions {
#   text {
#     content: "one"
#     begin_offset: 7
#   }
# }
#
# Entities:
# [{'entity': ('Ernest Bower', 'none', '')}, {'entity': ('countries', 'none', '')}, {'entity': ('earthquakes', 'none', '')}, {'entity': ('geography', 'none', '')}, {'entity': ('Center_for_Strategic_and_International_Studies', 'Q1053614', 'https://en.wikipedia.org/wiki/Center_for_Strategic_and_International_Studies')}, {'entity': ('studies', 'none', '')}, {'entity': ('Southeast_Asia', 'Q11708', 'https://en.wikipedia.org/wiki/Southeast_Asia')}, {'context': '"It is one of these countries, because of its geography, that doesn\'t have earthquakes," said Ernest Bower, senior adviser for Southeast Asia studies at the Center for Strategic and International Studies.'}]
# instances ==== [('Q155271', 'think tank'), ('Q82794', 'geographic region')]
# 4
# "It doesn't have tsunamis.
# ['"It doesn\'t have tsunamis.']
# "It doesn't have tsunamis.
# ---> tsunamis
# name: "tsunamis"
# type_: EVENT
# salience: 1.0
# mentions {
#   text {
#     content: "tsunamis"
#     begin_offset: 17
#   }
#   type_: COMMON
# }
#
# Entities:
# [{'entity': ('tsunamis', 'none', '')}, {'context': '"It doesn\'t have tsunamis.'}]
# 5
# It hasn't been tested with a disaster like this."
# ['It hasn\'t been tested with a disaster like this."']
# It hasn't been tested with a disaster like this."
# ---> this.
# name: "this."
# type_: OTHER
# salience: 0.6839195
# mentions {
#   text {
#     content: "this."
#     begin_offset: 43
#   }
#   type_: COMMON
# }
#
# ---> disaster
# name: "disaster"
# type_: EVENT
# salience: 0.3160805
# mentions {
#   text {
#     content: "disaster"
#     begin_offset: 29
#   }
#   type_: COMMON
# }
#
# Entities:
# [{'entity': ('disaster', 'none', '')}, {'context': 'It hasn\'t been tested with a disaster like this."'}]
# 6
# The disappearance of Malaysia Airlines Flight 370 has thrust the government into the dazzling glare of worldwide attention.
# ['The disappearance of Malaysia Airlines Flight 370 has thrust the government into the dazzling glare of worldwide attention.']
# The disappearance of Malaysia Airlines Flight 370 has thrust the government into the dazzling glare of worldwide attention.
# ---> disappearance
# name: "disappearance"
# type_: EVENT
# salience: 0.5685887
# mentions {
#   text {
#     content: "disappearance"
#     begin_offset: 4
#   }
#   type_: COMMON
# }
#
# ---> government
# name: "government"
# type_: ORGANIZATION
# salience: 0.16909976
# mentions {
#   text {
#     content: "government"
#     begin_offset: 65
#   }
#   type_: COMMON
# }
#
# ---> Malaysia Airlines Flight 370
# name: "Malaysia Airlines Flight 370"
# type_: OTHER
# metadata {
#   key: "mid"
#   value: "/m/0_x6q01"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Malaysia_Airlines_Flight_370"
# }
# salience: 0.11075962
# mentions {
#   text {
#     content: "Malaysia Airlines Flight 370"
#     begin_offset: 21
#   }
#   type_: PROPER
# }
#
# ---> attention
# name: "attention"
# type_: OTHER
# salience: 0.09260333
# mentions {
#   text {
#     content: "attention"
#     begin_offset: 113
#   }
#   type_: COMMON
# }
#
# ---> glare
# name: "glare"
# type_: OTHER
# salience: 0.058948617
# mentions {
#   text {
#     content: "glare"
#     begin_offset: 94
#   }
#   type_: COMMON
# }
#
# ---> 370
# name: "370"
# type_: NUMBER
# metadata {
#   key: "value"
#   value: "370"
# }
# mentions {
#   text {
#     content: "370"
#     begin_offset: 46
#   }
# }
#
# Entities:
# [{'entity': ('disappearance', 'none', '')}, {'entity': ('government', 'none', '')}, {'entity': ('Malaysia_Airlines_Flight_370', 'Q15908324', 'https://en.wikipedia.org/wiki/Malaysia_Airlines_Flight_370')}, {'entity': ('attention', 'none', '')}, {'entity': ('glare', 'none', '')}, {'entity': ('370', 'none', '')}, {'context': 'The disappearance of Malaysia Airlines Flight 370 has thrust the government into the dazzling glare of worldwide attention.'}]
# instances ==== [('Q744913', 'aviation accident')]
# 7
# And it hasn't emerged with very good grades.
# ["And it hasn't emerged with very good grades."]
# And it hasn't emerged with very good grades.
# ---> grades
# name: "grades"
# type_: OTHER
# salience: 1.0
# mentions {
#   text {
#     content: "grades"
#     begin_offset: 37
#   }
#   type_: COMMON
# }
#
# Entities:
# [{'entity': ('grades', 'none', '')}, {'context': "And it hasn't emerged with very good grades."}]
# 8
# "I think on a stress test, they're failing," Bower told CNN's Jake Tapper, pointing to the government's coordination of different agencies and communication with other countries.
# ['"I think on a stress test, they\'re failing," Bower told CNN\'s Jake Tapper, pointing to the government\'s coordination of different agencies and communication with other countries.']
# "I think on a stress test, they're failing," Bower told CNN's Jake Tapper, pointing to the government's coordination of different agencies and communication with other countries.
# ---> Bower
# name: "Bower"
# type_: PERSON
# salience: 0.57868713
# mentions {
#   text {
#     content: "Bower"
#     begin_offset: 45
#   }
#   type_: PROPER
# }
#
# ---> stress test
# name: "stress test"
# type_: OTHER
# salience: 0.12218864
# mentions {
#   text {
#     content: "stress test"
#     begin_offset: 14
#   }
#   type_: COMMON
# }
#
# ---> agencies
# name: "agencies"
# type_: ORGANIZATION
# salience: 0.05952984
# mentions {
#   text {
#     content: "agencies"
#     begin_offset: 130
#   }
#   type_: COMMON
# }
#
# ---> communication
# name: "communication"
# type_: OTHER
# salience: 0.05952984
# mentions {
#   text {
#     content: "communication"
#     begin_offset: 143
#   }
#   type_: COMMON
# }
#
# ---> CNN
# name: "CNN"
# type_: ORGANIZATION
# metadata {
#   key: "mid"
#   value: "/m/0gsgr"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/CNN"
# }
# salience: 0.05110344
# mentions {
#   text {
#     content: "CNN"
#     begin_offset: 56
#   }
#   type_: PROPER
# }
#
# ---> countries
# name: "countries"
# type_: LOCATION
# salience: 0.042018116
# mentions {
#   text {
#     content: "countries"
#     begin_offset: 168
#   }
#   type_: COMMON
# }
#
# ---> Jake Tapper
# name: "Jake Tapper"
# type_: PERSON
# metadata {
#   key: "mid"
#   value: "/m/06sf9n"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Jake_Tapper"
# }
# salience: 0.033909254
# mentions {
#   text {
#     content: "Jake Tapper"
#     begin_offset: 62
#   }
#   type_: PROPER
# }
#
# ---> coordination
# name: "coordination"
# type_: OTHER
# salience: 0.026516855
# mentions {
#   text {
#     content: "coordination"
#     begin_offset: 104
#   }
#   type_: COMMON
# }
#
# ---> government
# name: "government"
# type_: ORGANIZATION
# salience: 0.026516855
# mentions {
#   text {
#     content: "government"
#     begin_offset: 91
#   }
#   type_: COMMON
# }
#
# Entities:
# [{'entity': ('Bower', 'none', '')}, {'entity': ('stress test', 'none', '')}, {'entity': ('agencies', 'none', '')}, {'entity': ('communication', 'none', '')}, {'entity': ('CNN', 'Q48340', 'https://en.wikipedia.org/wiki/CNN')}, {'entity': ('countries', 'none', '')}, {'entity': ('Jake_Tapper', 'Q6125032', 'https://en.wikipedia.org/wiki/Jake_Tapper')}, {'entity': ('coordination', 'none', '')}, {'entity': ('government', 'none', '')}, {'context': '"I think on a stress test, they\'re failing," Bower told CNN\'s Jake Tapper, pointing to the government\'s coordination of different agencies and communication with other countries.'}]
# instances ==== [('Q7892363', 'United States cable news'), ('Q5', 'human')]
# 9
#  China among critics Criticism and complaints have come from other countries involved in the search for the missing plane, including China and Vietnam, and from the relatives of passengers.
# [' China among critics Criticism and complaints have come from other countries involved in the search for the missing plane, including China and Vietnam, and from the relatives of passengers.']
#  China among critics Criticism and complaints have come from other countries involved in the search for the missing plane, including China and Vietnam, and from the relatives of passengers.
# ---> critics
# name: "critics"
# type_: PERSON
# salience: 0.25281912
# mentions {
#   text {
#     content: "critics"
#     begin_offset: 13
#   }
#   type_: COMMON
# }
#
# ---> China
# name: "China"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/0d05w3"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/China"
# }
# salience: 0.20323905
# mentions {
#   text {
#     content: "China"
#     begin_offset: 1
#   }
#   type_: PROPER
# }
# mentions {
#   text {
#     content: "China"
#     begin_offset: 133
#   }
#   type_: PROPER
# }
#
# ---> Criticism
# name: "Criticism"
# type_: OTHER
# metadata {
#   key: "mid"
#   value: "/m/09g7cvx"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Criticism"
# }
# salience: 0.15993068
# mentions {
#   text {
#     content: "Criticism"
#     begin_offset: 21
#   }
#   type_: PROPER
# }
#
# ---> complaints
# name: "complaints"
# type_: OTHER
# salience: 0.09407218
# mentions {
#   text {
#     content: "complaints"
#     begin_offset: 35
#   }
#   type_: COMMON
# }
#
# ---> search
# name: "search"
# type_: EVENT
# salience: 0.065463424
# mentions {
#   text {
#     content: "search"
#     begin_offset: 93
#   }
#   type_: COMMON
# }
#
# ---> countries
# name: "countries"
# type_: ORGANIZATION
# salience: 0.06469516
# mentions {
#   text {
#     content: "countries"
#     begin_offset: 67
#   }
#   type_: COMMON
# }
#
# ---> plane
# name: "plane"
# type_: OTHER
# salience: 0.06026378
# mentions {
#   text {
#     content: "plane"
#     begin_offset: 116
#   }
#   type_: COMMON
# }
#
# ---> relatives
# name: "relatives"
# type_: PERSON
# salience: 0.045831606
# mentions {
#   text {
#     content: "relatives"
#     begin_offset: 165
#   }
#   type_: COMMON
# }
#
# ---> passengers
# name: "passengers"
# type_: PERSON
# salience: 0.032349452
# mentions {
#   text {
#     content: "passengers"
#     begin_offset: 178
#   }
#   type_: COMMON
# }
#
# ---> Vietnam
# name: "Vietnam"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/01crd5"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Vietnam"
# }
# salience: 0.012124179
# mentions {
#   text {
#     content: "Vietnam"
#     begin_offset: 143
#   }
#   type_: PROPER
# }
#
# Entities:
# [{'entity': ('critics', 'none', '')}, {'entity': ('China', 'Q148', 'https://en.wikipedia.org/wiki/China')}, {'entity': ('Criticism', 'Q17955', 'https://en.wikipedia.org/wiki/Criticism')}, {'entity': ('complaints', 'none', '')}, {'entity': ('search', 'none', '')}, {'entity': ('countries', 'none', '')}, {'entity': ('plane', 'none', '')}, {'entity': ('relatives', 'none', '')}, {'entity': ('passengers', 'none', '')}, {'entity': ('Vietnam', 'Q881', 'https://en.wikipedia.org/wiki/Vietnam')}, {'context': ' China among critics Criticism and complaints have come from other countries involved in the search for the missing plane, including China and Vietnam, and from the relatives of passengers.'}]
# instances ==== [('Q4894405', 'journalism genre'), ('Q3624078', 'sovereign state'), ('Q881', 'Vietnam')]
# 10
#  Malaysian officials have created confusion by issuing contradictory statements on key aspects of the investigation.
# [' Malaysian officials have created confusion by issuing contradictory statements on key aspects of the investigation.']
#  Malaysian officials have created confusion by issuing contradictory statements on key aspects of the investigation.
# ---> officials
# name: "officials"
# type_: PERSON
# salience: 0.3484438
# mentions {
#   text {
#     content: "officials"
#     begin_offset: 11
#   }
#   type_: COMMON
# }
#
# ---> Malaysian
# name: "Malaysian"
# type_: LOCATION
# salience: 0.22778434
# mentions {
#   text {
#     content: "Malaysian"
#     begin_offset: 1
#   }
#   type_: PROPER
# }
#
# ---> statements
# name: "statements"
# type_: OTHER
# salience: 0.15771753
# mentions {
#   text {
#     content: "statements"
#     begin_offset: 69
#   }
#   type_: COMMON
# }
#
# ---> confusion
# name: "confusion"
# type_: OTHER
# salience: 0.15427966
# mentions {
#   text {
#     content: "confusion"
#     begin_offset: 34
#   }
#   type_: COMMON
# }
#
# ---> investigation
# name: "investigation"
# type_: EVENT
# salience: 0.07701702
# mentions {
#   text {
#     content: "investigation"
#     begin_offset: 102
#   }
#   type_: COMMON
# }
#
# ---> aspects
# name: "aspects"
# type_: OTHER
# salience: 0.03475766
# mentions {
#   text {
#     content: "aspects"
#     begin_offset: 87
#   }
#   type_: COMMON
# }
#
# Entities:
# [{'entity': ('officials', 'none', '')}, {'entity': ('Malaysian', 'none', '')}, {'entity': ('statements', 'none', '')}, {'entity': ('confusion', 'none', '')}, {'entity': ('investigation', 'none', '')}, {'entity': ('aspects', 'none', '')}, {'context': ' Malaysian officials have created confusion by issuing contradictory statements on key aspects of the investigation.'}]
# 11
#  The majority of the people on board the plane were Chinese, and Beijing has increasingly voiced its displeasure with the search, especially after Malaysia announced over the weekend that evidence suggested the plane had been deliberately flown west into the Indian Ocean, away from its last confirmed location over the South China Sea.
# [' The majority of the people on board the plane were Chinese, and Beijing has increasingly voiced its displeasure with the search, especially after Malaysia announced over the weekend that evidence suggested the plane had been deliberately flown west into the Indian Ocean, away from its last confirmed location over the South China Sea.']
#  The majority of the people on board the plane were Chinese, and Beijing has increasingly voiced its displeasure with the search, especially after Malaysia announced over the weekend that evidence suggested the plane had been deliberately flown west into the Indian Ocean, away from its last confirmed location over the South China Sea.
# ---> Beijing
# name: "Beijing"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/01914"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Beijing"
# }
# salience: 0.17761141
# mentions {
#   text {
#     content: "Beijing"
#     begin_offset: 65
#   }
#   type_: PROPER
# }
#
# ---> people
# name: "people"
# type_: PERSON
# salience: 0.15328653
# mentions {
#   text {
#     content: "people"
#     begin_offset: 21
#   }
#   type_: COMMON
# }
#
# ---> board
# name: "board"
# type_: OTHER
# salience: 0.15328653
# mentions {
#   text {
#     content: "board"
#     begin_offset: 31
#   }
#   type_: COMMON
# }
#
# ---> Malaysia
# name: "Malaysia"
# type_: ORGANIZATION
# metadata {
#   key: "mid"
#   value: "/m/09pmkv"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Malaysia"
# }
# salience: 0.11642881
# mentions {
#   text {
#     content: "Malaysia"
#     begin_offset: 147
#   }
#   type_: PROPER
# }
#
# ---> majority
# name: "majority"
# type_: OTHER
# salience: 0.07213303
# mentions {
#   text {
#     content: "majority"
#     begin_offset: 5
#   }
#   type_: COMMON
# }
#
# ---> plane
# name: "plane"
# type_: OTHER
# salience: 0.0700834
# mentions {
#   text {
#     content: "plane"
#     begin_offset: 41
#   }
#   type_: COMMON
# }
#
# ---> plane
# name: "plane"
# type_: OTHER
# salience: 0.044674784
# mentions {
#   text {
#     content: "plane"
#     begin_offset: 211
#   }
#   type_: COMMON
# }
#
# ---> search
# name: "search"
# type_: EVENT
# salience: 0.042313185
# mentions {
#   text {
#     content: "search"
#     begin_offset: 122
#   }
#   type_: COMMON
# }
#
# ---> displeasure
# name: "displeasure"
# type_: OTHER
# salience: 0.042313185
# mentions {
#   text {
#     content: "displeasure"
#     begin_offset: 101
#   }
#   type_: COMMON
# }
#
# ---> evidence
# name: "evidence"
# type_: OTHER
# salience: 0.039378643
# mentions {
#   text {
#     content: "evidence"
#     begin_offset: 188
#   }
#   type_: COMMON
# }
#
# ---> Chinese
# name: "Chinese"
# type_: LOCATION
# salience: 0.037202664
# mentions {
#   text {
#     content: "Chinese"
#     begin_offset: 52
#   }
#   type_: PROPER
# }
#
# ---> location
# name: "location"
# type_: LOCATION
# salience: 0.021016615
# mentions {
#   text {
#     content: "location"
#     begin_offset: 302
#   }
#   type_: COMMON
# }
#
# ---> Indian Ocean
# name: "Indian Ocean"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/03rz4"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Indian_Ocean"
# }
# salience: 0.017784178
# mentions {
#   text {
#     content: "Indian Ocean"
#     begin_offset: 259
#   }
#   type_: PROPER
# }
#
# ---> South China Sea
# name: "South China Sea"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/0jtm8"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/South_China_Sea"
# }
# salience: 0.012487034
# mentions {
#   text {
#     content: "South China Sea"
#     begin_offset: 320
#   }
#   type_: PROPER
# }
# Entities:
# [{'entity': ('Beijing', 'Q956', 'https://en.wikipedia.org/wiki/Beijing')}, {'entity': ('people', 'none', '')}, {'entity': ('board', 'none', '')}, {'entity': ('Malaysia', 'Q833', 'https://en.wikipedia.org/wiki/Malaysia')}, {'entity': ('majority', 'none', '')}, {'entity': ('plane', 'none', '')}, {'entity': ('plane', 'none', '')}, {'entity': ('search', 'none', '')}, {'entity': ('displeasure', 'none', '')}, {'entity': ('evidence', 'none', '')}, {'entity': ('Chinese', 'none', '')}, {'entity': ('location', 'none', '')}, {'entity': ('Indian_Ocean', 'Q1239', 'https://en.wikipedia.org/wiki/Indian_Ocean')}, {'entity': ('South_China_Sea', 'Q37660', 'https://en.wikipedia.org/wiki/South_China_Sea')}, {'context': ' The majority of the people on board the plane were Chinese, and Beijing has increasingly voiced its displeasure with the search, especially after Malaysia announced over the weekend that evidence suggested the plane had been deliberately flown west into the Indian Ocean, away from its last confirmed location over the South China Sea.'}]
# instances ==== [('Q165', 'sea'), ('Q3624078', 'sovereign state'), ('Q9430', 'ocean'), ('Q5119', 'capital')]
# 12
#  "The new information means the intensive search in the South China Sea for the whole past week was worthless and would never bear fruit," said a commentary published by China's state-run news agency Xinhua.
# [' "The new information means the intensive search in the South China Sea for the whole past week was worthless and would never bear fruit," said a commentary published by China\'s state-run news agency Xinhua.']
#  "The new information means the intensive search in the South China Sea for the whole past week was worthless and would never bear fruit," said a commentary published by China's state-run news agency Xinhua.
# ---> information
# name: "information"
# type_: OTHER
# salience: 0.37014833
# mentions {
#   text {
#     content: "information"
#     begin_offset: 10
#   }
#   type_: COMMON
# }
#
# ---> search
# name: "search"
# type_: EVENT
# salience: 0.2024083
# mentions {
#   text {
#     content: "search"
#     begin_offset: 42
#   }
#   type_: COMMON
# }
#
# ---> Xinhua
# name: "Xinhua"
# type_: ORGANIZATION
# metadata {
#   key: "mid"
#   value: "/m/01n13b"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/Xinhua_News_Agency"
# }
# salience: 0.13706687
# mentions {
#   text {
#     content: "news agency"
#     begin_offset: 188
#   }
#   type_: COMMON
# }
# mentions {
#   text {
#     content: "Xinhua"
#     begin_offset: 200
#   }
#   type_: PROPER
# }
#
# ---> fruit
# name: "fruit"
# type_: OTHER
# salience: 0.11678232
# mentions {
#   text {
#     content: "fruit"
#     begin_offset: 131
#   }
#   type_: COMMON
# }
#
# ---> South China Sea
# name: "South China Sea"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/0jtm8"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/South_China_Sea"
# }
# salience: 0.075716734
# mentions {
#   text {
#     content: "South China Sea"
#     begin_offset: 56
#   }
#   type_: PROPER
# }
#
# ---> China
# name: "China"
# type_: LOCATION
# metadata {
#   key: "mid"
#   value: "/m/0d05w3"
# }
# metadata {
#   key: "wikipedia_url"
#   value: "https://en.wikipedia.org/wiki/China"
# }
# salience: 0.06073689
# mentions {
#   text {
#     content: "China"
#     begin_offset: 170
#   }
#   type_: PROPER
# }
#
# ---> commentary
# name: "commentary"
# type_: WORK_OF_ART
# salience: 0.037140556
# mentions {
#   text {
#     content: "commentary"
#     begin_offset: 146
#   }
#   type_: COMMON
# }
#
# Entities:
# [{'entity': ('information', 'none', '')}, {'entity': ('search', 'none', '')}, {'entity': ('Xinhua_News_Agency', 'Q204839', 'https://en.wikipedia.org/wiki/Xinhua_News_Agency')}, {'entity': ('fruit', 'none', '')}, {'entity': ('South_China_Sea', 'Q37660', 'https://en.wikipedia.org/wiki/South_China_Sea')}, {'entity': ('China', 'Q148', 'https://en.wikipedia.org/wiki/China')}, {'entity': ('commentary', 'none', '')}, {'context': ' "The new information means the intensive search in the South China Sea for the whole past week was worthless and would never bear fruit," said a commentary published by China\'s state-run news agency Xinhua.'}]
# instances ==== [('Q165', 'sea'), ('Q192283', 'news agency'), ('Q3624078', 'sovereign state')]
# 13
#  "Even worse, the golden time for saving possible survivors, if any, was generously wasted."
# [' "Even worse, the golden time for saving possible survivors, if any, was generously wasted."']
#  "Even worse, the golden time for saving possible survivors, if any, was generously wasted."
# ---> survivors
# name: "survivors"
# type_: PERSON
# salience: 0.7445061
# mentions {
#   text {
#     content: "survivors"
#     begin_offset: 50
#   }
#   type_: COMMON
# }
#
# ---> any
# name: "any"
# type_: OTHER
# salience: 0.25549388
# mentions {
#   text {
#     content: "any"
#     begin_offset: 64
#   }
#   type_: COMMON
# }
#
# Entities:
# [{'entity': ('survivors', 'none', '')}, {'context': ' "Even worse, the golden time for saving possible survivors, if any, was generously wasted."'}]
# 14

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
def showGraph(sg):
    options = {
        'node_size': 3000,
        'font_weight': 'bold',
         'edgecolors':'black',
        'width': 2,
    }
    labels = {}
    color = []
    for n in sg.nodes:
        d =sg.nodes[n]
        #print(d)
        color.append(d['color'])
        labels[n]=n
    
    #print(color)
        #print(sg.nodes[x]['url'])
        #labels[]
        
    plt.figure(3,figsize=(15,15)) 

    nx.draw(sg, labels = labels, node_color = color, **options)

# %%
showGraph(G)

# %% [markdown]
# utilities to inspect graph nodes.

# %%
def showArticle(graph, name):
    print(name, graph.nodes[name]['context'])
    print('all edges from this node are:')
    for x in graph.edges():
        if x[1] == name:
            print(x, graph.nodes[x[0]]['url'], graph.nodes[x[0]]['wikiID'])
            

def showEntity(graph, name):
    instances = []
    classes = []
    print(name,' wikiID=', graph.nodes[name]['wikiID'], 'wikipedia url =', graph.nodes[name]['url'])
    print(graph.nodes[name]['description'])
    inst = graph.nodes[name]['instanceof'] 
    if inst != []:
        instances = instances +inst
        ilist = [i[1] for i in inst]
        print('is an instance of ', ilist)

# %%
showEntity(G, 'campaign')

# %%
showEntity(G, 'political party')

# %%
showArticle(G,"Art2")

# %% [markdown]
# Some book keeping

# %%
instances = []
classes = []
lines = []
ent_cnt = 0
for nd in G.nodes:
    #print(G.nodes[nd])
    node = G.nodes[nd]
    if node['flavor'] == 'entity':
        ent_cnt +=1
        inst = node['instanceof']
        instances = instances + inst
        clas = node['subclassof']
        classes = classes + clas
    elif node['flavor'] == 'article':
        #print('doing art ',nd, node)
        lines.append([node['context'], nd])
instanceSet = set(instances)
instances = list(instanceSet)
classSet = set(classes)
classes = list(classSet)
print('instances =', len(instances))
print("---------------")
print('classes =', len(classes))
print('lines =', len(lines))
print('entities = ', ent_cnt)
# Out:
# instances = 9
# ---------------
# classes = 0
# lines = 15
# entities =  39

# %%
sentences = [lines[i][0] for i in range(len(lines))]

# %%
keys = [lines[i][1] for i in range(len(lines))]

# %%
keys
# Out:
# ['Art0',
#  'Art1',
#  'Art2',
#  'Art3',
#  'Art4',
#  'Art5',
#  'Art6',
#  'Art7',
#  'Art8',
#  'Art9',
#  'Art10',
#  'Art11',
#  'Art12',
#  'Art13',
#  'Art14']

# %%
sentences
# Out:
# ['Animated history of the US.',
#  'Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.',
#  'But it makes a valid claim which you ignore entirely: That the strategy to promote "gun rights" for white people and to outlaw gun possession by black people was a way to uphold racism without letting an openly terrorist organization like the KKK flourish.',
#  'Did the 19th century NRA in the southern states promote gun rights for black people?',
#  'I highly doubt it.',
#  "But if they didn't, one of their functions was to continue the racism of the KKK.",
#  'This is the key message of this part of the animation, which is again being ignored by its critics.',
#  'Buell shooting in Flint.',
#  'You write: "Fact: The little boy was the class thug, already suspended from school for stabbing another kid with a pencil, and had fought with Kayla the day before".',
#  " This characterization of a six-year-old as a pencil-stabbing thug is exactly the kind of hysteria that Moore's film warns against.",
#  ' It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.',
#  ' The kid was a little bastard, and the parents were involved in drugs -- case closed.',
#  ' But why do people deal with drugs?',
#  " Because it's so much fun to do so?",
#  ' It is by now well documented that the CIA tolerated crack sales in US cities to fund the operation of South American "contras" It is equally well known that the so-called "war on drugs" begun under the Nixon administration is a failure which has cost hundreds of billions and made America the world leader in prison population (both in relative and absolute numbers).']

# %% [markdown]
# ### WITH USE EMBEDDINGS

# %%
import tensorflow as tf
import tensorflow_hub as hub
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder-large/5")

# %% [markdown]
# ### Loading Existing Embeddings for Basic Find_Best

# %%
Para_Embeddings = np.load('Para_Embeddings.npy', allow_pickle=True)

# %%
Para_Embeddings[0]
# Out:
# <tf.Tensor: shape=(15, 512), dtype=float32, numpy=
# array([[-0.01274004, -0.11565759,  0.03097722, ...,  0.02448403,
#          0.00251936,  0.04266088],
#        [-0.06971727, -0.04264623,  0.05854981, ..., -0.01652756,
#          0.03496636,  0.0289634 ],
#        [-0.01743965, -0.09696124, -0.11560833, ...,  0.05650649,
#          0.04247527, -0.00178425],
#        ...,
#        [ 0.03638124, -0.05021678, -0.01674846, ..., -0.00129548,
#          0.03262155, -0.00195663],
#        [ 0.03838673, -0.01887815,  0.03731984, ..., -0.04768466,
#         -0.02261458, -0.0073561 ],
#        [ 0.02464328, -0.02262432,  0.03899401, ..., -0.04800109,
#          0.06842233, -0.0242082 ]], dtype=float32)>

# %%
Ques_Embeddings = np.load('Ques_Embeddings.npy', allow_pickle=True)

# %%
Ques_Embeddings[0]
# Out:
# <tf.Tensor: shape=(12, 512), dtype=float32, numpy=
# array([[-0.02335444, -0.02437302, -0.08582116, ...,  0.05580284,
#          0.01404525,  0.03490542],
#        [ 0.06067836,  0.00770691,  0.02357497, ..., -0.0135384 ,
#         -0.10253123,  0.05588945],
#        [ 0.00332781,  0.03157982,  0.06085844, ...,  0.09408785,
#         -0.02388284,  0.02756161],
#        ...,
#        [ 0.09039148, -0.03301139,  0.04262282, ...,  0.06946719,
#         -0.07055496,  0.03527693],
#        [ 0.04434222, -0.02122178,  0.02624882, ..., -0.00422733,
#          0.00649624,  0.04344792],
#        [ 0.01403348, -0.05871298, -0.02489756, ..., -0.04201954,
#         -0.030848  ,  0.00154308]], dtype=float32)>

# %%
def find_in_keys(nodeid):
    for i in range(len(keys)):
        if nodeid == keys[i]:
            return i
    return -1

# %%
mar = Para_Embeddings[Para_Num]

# %% [markdown]
# ## The function find_best
# this function takes a sentence and look for the k closest matches based on proximity to the BERT model vectors stored in mar.   This uses dotproduct of normalized vectors which is the same as cosine distance.

# %%
def find_best_use(k, ques, show=True):
    v0 =  ques
    norms = []
    for i in range(mar.shape[0]):
        norms.append([np.dot(v0,mar[i]), i])
    norms.sort(reverse=True)
    if show:
        print('top ',k, ' related nodes' )
    #print(norms[0][1])
    nodename = keys[norms[0][1]]
    for i in range(k):
        node = keys[norms[i][1]]
        if show:
            print(node)
            print(sentences[norms[i][1]])
    return norms[0:k]

# %% [markdown]
# #### Testing with Qs from Dataset

# %%
for i in range(Num_of_Qs):
    ques_num = i
    ques = Ques_Embeddings[Para_Num][ques_num]
    ques_text = data_qs[Para_Num][ques_num]
    print("Ques:", ques_text)
    Num_of_Ans = len(Answer_Para[i])
    Answers_Got = [x[1] for x in find_best_use(Num_of_Ans, ques)]
    Correct_Answers = Answer_Para[i]
    print("Got:",Answers_Got)
    print("Correct",Correct_Answers)
# Out:
# Ques: What are two example of natural disasters that Malaysia does not experience?
# top  3  related nodes
# Art7
# Buell shooting in Flint.
# Art0
# Animated history of the US.
# Art10
#  It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.
# Got: [7, 0, 10]
# Correct [2, 3, 4]
# Ques: Why are Chinese and Vietnamese officials critical of the Malaysian response?
# top  4  related nodes
# Art10
#  It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.
# Art12
#  But why do people deal with drugs?
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Art6
# This is the key message of this part of the animation, which is again being ignored by its critics.
# Got: [10, 12, 1, 6]
# Correct [9, 10, 11, 13]
# Ques: What has the new information from Malaysia potentially wasted time for?
# top  2  related nodes
# Art7
# Buell shooting in Flint.
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Got: [7, 1]
# Correct [12, 13]
# Ques: What neighboring countries of Malaysia have recently suffered natural disasters?
# top  2  related nodes
# Art7
# Buell shooting in Flint.
# Art3
# Did the 19th century NRA in the southern states promote gun rights for black people?
# Got: [7, 3]
# Correct [0, 1]
# Ques: Contradictory statements by the government of Malaysia have irritated what country involved with the investigation?
# top  2  related nodes
# Art10
#  It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.
# Art7
# Buell shooting in Flint.
# Got: [10, 7]
# Correct [10, 11]
# Ques: According to the media, has the Malaysian government done well in responding to the disappearance of Flight 370?
# top  3  related nodes
# Art7
# Buell shooting in Flint.
# Art14
#  It is by now well documented that the CIA tolerated crack sales in US cities to fund the operation of South American "contras" It is equally well known that the so-called "war on drugs" begun under the Nixon administration is a failure which has cost hundreds of billions and made America the world leader in prison population (both in relative and absolute numbers).
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Got: [7, 14, 1]
# Correct [6, 7, 8]
# Ques: Who was critical of Malaysia's response?
# top  2  related nodes
# Art10
#  It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.
# Art6
# This is the key message of this part of the animation, which is again being ignored by its critics.
# Got: [10, 6]
# Correct [9, 3]
# Ques: Why might Malaysia not suffer the kinds of natural disasters experienced in Indonesia and the Philippines?
# top  4  related nodes
# Art12
#  But why do people deal with drugs?
# Art7
# Buell shooting in Flint.
# Art5
# But if they didn't, one of their functions was to continue the racism of the KKK.
# Art13
#  Because it's so much fun to do so?
# Got: [12, 7, 5, 13]
# Correct [0, 1, 3, 4]
# Ques: What natural disasters does Malaysia not have?
# top  2  related nodes
# Art7
# Buell shooting in Flint.
# Art0
# Animated history of the US.
# Got: [7, 0]
# Correct [3, 4]
# Ques: Of what nationality were the majority of people aboard Malaysia Airlines Flight 370?
# top  2  related nodes
# Art3
# Did the 19th century NRA in the southern states promote gun rights for black people?
# Art5
# But if they didn't, one of their functions was to continue the racism of the KKK.
# Got: [3, 5]
# Correct [11, 6]
# Ques: What kind of grades has Malaysia received concerning its handling of the disappearance of Malaysia Airlines Flight 370?
# top  2  related nodes
# Art7
# Buell shooting in Flint.
# Art14
#  It is by now well documented that the CIA tolerated crack sales in US cities to fund the operation of South American "contras" It is equally well known that the so-called "war on drugs" begun under the Nixon administration is a failure which has cost hundreds of billions and made America the world leader in prison population (both in relative and absolute numbers).
# Got: [7, 14]
# Correct [6, 7]
# Ques: Why is it thought that the intensive search in the South China Sea was worthless?
# top  2  related nodes
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Art12
#  But why do people deal with drugs?
# Got: [1, 12]
# Correct [11, 12]

# %%
ques_num = 6

# %%
ques = Ques_Embeddings[Para_Num][ques_num]
ques_text = data_qs[Para_Num][ques_num]
print("Ques:", ques_text)
find_best_use(4, ques)
# Out:
# Ques: It is believed that which group tolerated crack sales raising what other questions>
# top  4  related nodes
# Art2
# But it makes a valid claim which you ignore entirely: That the strategy to promote "gun rights" for white people and to outlaw gun possession by black people was a way to uphold racism without letting an openly terrorist organization like the KKK flourish.
# Art14
#  It is by now well documented that the CIA tolerated crack sales in US cities to fund the operation of South American "contras" It is equally well known that the so-called "war on drugs" begun under the Nixon administration is a failure which has cost hundreds of billions and made America the world leader in prison population (both in relative and absolute numbers).
# Art3
# Did the 19th century NRA in the southern states promote gun rights for black people?
# Art9
#  This characterization of a six-year-old as a pencil-stabbing thug is exactly the kind of hysteria that Moore's film warns against.
# [[0.25346643, 2], [0.25335282, 14], [0.22110768, 3], [0.17004359, 9]]

# %% [markdown]
# ## find_best3
# is the same as find_best but we remove candidates that are not in the same connected component.  note: k must be less than 40.

# %%
def find_best_use3(k, ques, show=True):
    v0 =  ques
    norms = []
    for i in range(mar.shape[0]):
        norms.append([np.dot(v0,mar[i]), i])
    norms.sort(reverse=True)
    nodename = keys[norms[0][1]]
    newlist = []
    nopath = 0
    for i in range(len(mar)):
        #print(norms[i])
        x = norms[i][1]
        try:
            path = nx.shortest_path(G, nodename, 'Art'+str(x))
            #print(path)
            newlist.append(norms[i])
        except:
            nopath += 1
    norms = newlist
    ln = len(norms)
    if show:
        print('top ',k, ' related nodes' )
        if ln < k:
            print('but only found ', ln)
    
    #print(norms[0][1])
    nodename = keys[norms[0][1]]
    category =  G.nodes[nodename]['source']
    for i in range(min(ln, k)):
        node = keys[norms[i][1]]
        if show:
            print(node)
            print(sentences[norms[i][1]])

    return min(ln, k)

# %%
ques_num = 6

# %%
ques = Ques_Embeddings[Para_Num][ques_num]
ques_text = data_qs[Para_Num][ques_num]
print("Ques:", ques_text)
find_best_use3(4, ques)
# Out:
# Ques: It is believed that which group tolerated crack sales raising what other questions>
# top  4  related nodes
# but only found  3
# Art2
# But it makes a valid claim which you ignore entirely: That the strategy to promote "gun rights" for white people and to outlaw gun possession by black people was a way to uphold racism without letting an openly terrorist organization like the KKK flourish.
# Art3
# Did the 19th century NRA in the southern states promote gun rights for black people?
# Art5
# But if they didn't, one of their functions was to continue the racism of the KKK.
# 3

# %% [markdown]
# ## find_best2
# the function find_best2 is more complicated.
#
# The function findClue extracts entities from the sentence and then looks for the closest match in all of the articles among those that have the same entities.  if there are more than 2 with the max number of matches we just give up and return [].
#
# To compute the convolutions we need to find all the neighbors of each node.  two nodes are neighbors if they share an entity node.   note that in the computation of findNeighbors we exclude two super nodes "albert_einstein" and "earth".   these node make too many nodes neighbors.
#
# ComputeMar2 is the function that computes the convolution matrix mar2.
#
# Function find_best_wl2 is a version of find_best that uses a article nodeID rather than a document to rank near nodes (based on mar2)  it is a utility used in find_best2
#
# Function find_best2 looks for clues.  there are either 0, 1 or 2 clues.   if there are 0 clues we use find_best(1 ...) to give us a guess.    if there are 1 or 2 clues we use them in find_best_wl2 to complete the list.  (in the case of 2 clues we use the first clue to generate the first two replies and the second clue to get the rest.

# %%
def findClue(G, sent, show = True):
    cls = entityExtractorBlock(sent)
    #Format returned in : (ent.name, wikidataId, wikipage)
    if(cls==[]):
        cls = get_ents(sent)
        #print("clues",cls)
    #print("Normal Clues",cls)
    clsent = [x[0] for x in cls]
    if show:
        print(clsent)
    arts = []
    for x in cls:
        item = x[0]
        for edg in G.edges():
            #print(edg)
            if edg[0] == item and G.nodes[edg[1]]['flavor'] == 'article':
                arts.append(edg[1])
    artset = set(arts)
    artnames = list(artset)
    factoredartnames = []
    for art in artnames:
        #context = G.nodes[art]['context']
        #print('context=',context)
        cls1ent = G.nodes[art]['ent-list']
        #cls1ent = [x[0] for x in cls1]
        cls1int = set(clsent).intersection(set(cls1ent))
        if cls1int != set():
            factoredartnames.append((art, len(cls1int)))
        artnames = [x[0] for x in factoredartnames]
    if show:
        print('artnames=',artnames)
    dic = {}
    for x in artnames:
        dic[x] = 0
    for x in factoredartnames:
        dic[x[0]] = x[1]
    #print('DIC =',dic)
    bmax = 0
    bestmax = ''
    for x in artnames:
        if dic[x] > bmax:
            bmax = dic[x]
            #print(x)
            bestmax = x
    count_ties = 0
    tie_list = []
    for x in artnames:
        if dic[x] == bmax:
            count_ties += 1
            tie_list.append(x)
    if show:
        print(count_ties, 'nodes out of',len(artnames), 'matched the max value of ', bmax)
    if count_ties >  0.5*len(artnames) and len(artnames)> 2:
        return  []
    return tie_list
   

def findNeighbors(g, art):
    n = g.nodes[art]
    #print(n)
    features = []
    neighbors = []
    for x in g.edges:
        if x[1] == art:
            #print('found art in ',x)
            p = x[0]
            features.append(p)
            for y in g.edges:
                    if y[0] == p:
                        if y[1] != art:
                            #print(y[1][0:3])
                            if y[1][0:3] != 'Art':
                                features.append(y[1])
                            else:
                                neighbors.append(y[1])
    return neighbors, features

mar2 = np.zeros((mar.shape[0], mar.shape[1]))
def computeMar2(G, mar, lambd): #Graph Convolution Function
    num_zero_neighbors = 0
    tot_neighbors = 0
    num_arts = 0
    for art in G.nodes():
        if G.nodes[art]['flavor'] == 'article':
            num_arts += 1.0
            neighbors, features =  findNeighbors(G, art)
            print("Article:",art)
            print("neighbours", neighbors)
            print("features", features)
            v = np.zeros(mar.shape[1])
            c = 0.0
            if len(neighbors) == 0:
                num_zero_neighbors +=1
            tot_neighbors += len(neighbors)
            if len(neighbors) > 0:
                for x in neighbors:
                    loc = find_in_keys(x)
                    v = v + mar[loc]
                    c = c+1.0
                v = v/c
                z = lambd*mar[find_in_keys(art)] + (1.0-lambd)*v
                z = z/np.linalg.norm(z)
                mar2[find_in_keys(art)] = z
            else:
                mar2[find_in_keys(art)] = mar[find_in_keys(art)]

    return num_zero_neighbors, tot_neighbors/num_arts


def find_best2(k, abstract,embedding,show=True):
    cls = findClue(G, abstract, show)
    print('clues are =', cls)
    if cls != []:
        best = cls[0]
    else:
        x = find_best_use(1, embedding, show=False)
        best = keys[x[0][1]]
    if(len(cls)> 1):
        normsa = find_best_wl2(2, cls[0], show)
        normsb = find_best_wl2(k-2, cls[1], show)
        norms = normsa+normsb
    else:
        norms = find_best_wl2(k, best, show)
    return norms


def find_best_wl2(k, nodeid, show=True):
    #print(nodeid)
    v0 = mar2[find_in_keys(nodeid)]
    norms = []
    for i in range(mar2.shape[0]):
        norms.append([np.dot(v0,mar2[i]), i])
    norms.sort(reverse=True)
    #if show:
    #    print('top ',k, ' related nodes' )
    nodename = keys[norms[0][1]]
    category =  G.nodes[nodename]['source']
    for i in range(k):
        node = keys[norms[i][1]]
        sent = sentences[norms[i][1]]
        #print('node = ', node)
        if show:
            print(node)
            print(sent)
    return norms[0:k]
            
def showRelated(G,art):
    print( G.nodes[art]['context'])
    neighbors, features =  findNeighbors(G, art)
    n = set(neighbors)
    neighbors = list(n)
    print(neighbors)
    for x in neighbors:
        print( G.nodes[x]['context'])
        v0 = mar[find_in_keys(art)]
        v1 = mar[find_in_keys(x)]
        print(" dot prod =", np.dot(v0,v1))
    print(features)

# %% [markdown]
# ## Compute mar2
# the embedding vectors for the convolution of the BERT embedding

# %%
computeMar2(G, mar, 0.8)
# Out:
# Article: Art0
# neighbours ['Art14']
# features ['United_States', 'United States of America']
# Article: Art1
# neighbours ['Art6']
# features ['cartoon', 'critic', 'part', 'film']
# Article: Art2
# neighbours ['Art3', 'Art5']
# features ['gun rights', 'gun possession', 'Ku_Klux_Klan', 'political organization']
# Article: Art3
# neighbours ['Art2']
# features ['gun rights', 'National_Rifle_Association', '501(c)(3) organization']
# Article: Art4
# neighbours []
# features ['none']
# Article: Art5
# neighbours ['Art2']
# features ['Ku_Klux_Klan', 'political organization']
# Article: Art6
# neighbours ['Art1']
# features ['critic', 'message', 'animation']
# Article: Art7
# neighbours []
# features ['Flint,_Michigan', 'city of the United States']
# Article: Art8
# neighbours []
# features ['class thug']
# Article: Art9
# neighbours []
# features ['pencil-stabbing thug']
# Article: Art10
# neighbours []
# features ['Republican_Party_(United_States)', 'political party']
# Article: Art11
# neighbours ['Art12']
# features ['kid', 'bastard', 'parent', 'drug', 'case']
# Article: Art12
# neighbours ['Art11']
# features ['drug', 'people']
# Article: Art13
# neighbours []
# features ['fun']
# Article: Art14
# neighbours ['Art0']
# features ['United_States', 'United States of America', 'Central_Intelligence_Agency', 'intelligence agency', 'crack sales', 'War_on_drugs', 'campaign', 'prison population', 'world leader', 'South_America', 'continent', 'Richard_Nixon', 'human']
# (6, 0.6666666666666666)

# %%
ques_num = 2

# %%
ques = Ques_Embeddings[Para_Num][ques_num]
ques_text = data_qs[Para_Num][ques_num]
print("Ques:", ques_text)
find_best2(4, ques_text,ques)
# Out:
# Ques: What type of the film is being discussed and what is on of the key messages?
# ['type', 'film', 'message']
# artnames= ['Art6', 'Art1']
# 2 nodes out of 2 matched the max value of  1
# clues are = ['Art6', 'Art1']
# Art6
# This is the key message of this part of the animation, which is again being ignored by its critics.
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Art6
# This is the key message of this part of the animation, which is again being ignored by its critics.
# [[0.9999999814246305, 6],
#  [0.7472159328206298, 1],
#  [1.0000000641424818, 1],
#  [0.7472159328206298, 6]]

# %% [markdown]
# ### USE with Convoluted Embeddings for Articles

# %%
mar2 = np.zeros((mar.shape[0], mar.shape[1]))
def computeMar2(G, mar, lambd): #Graph Convolution Function
    num_zero_neighbors = 0
    tot_neighbors = 0
    num_arts = 0
    for art in G.nodes():
        if G.nodes[art]['flavor'] == 'article':
            num_arts += 1.0
            neighbors, features =  findNeighbors(G, art)
            print("Article:",art)
            print("neighbours", neighbors)
            print("features", features)
            v = np.zeros(mar.shape[1])
            c = 0.0
            if len(neighbors) == 0:
                num_zero_neighbors +=1
            tot_neighbors += len(neighbors)
            if len(neighbors) > 0:
                for x in neighbors:
                    loc = find_in_keys(x)
                    v = v + mar[loc]
                    c = c+1.0
                v = v/c
                z = lambd*mar[find_in_keys(art)] + (1.0-lambd)*v
                z = z/np.linalg.norm(z)
                mar2[find_in_keys(art)] = z
            else:
                mar2[find_in_keys(art)] = mar[find_in_keys(art)]

    return num_zero_neighbors, tot_neighbors/num_arts

# %%
computeMar2(G, mar, 0.8)
# Out:
# Article: Art0
# neighbours ['Art2', 'Art11', 'Art6']
# features ['Malaysia', 'sovereign state', 'disappearance', 'country', 'passenger jets', 'headlines', 'world']
# Article: Art1
# neighbours ['Art3']
# features ['Southeast_Asia', 'geographic region', 'neighbors', 'media frenzy', 'disasters', 'Philippines', 'Indonesia', 'crisis']
# Article: Art2
# neighbours ['Art0', 'Art11']
# features ['Malaysia', 'sovereign state', 'spotlight', 'independence', 'United_Kingdom', 'permanent member', 'rule']
# Article: Art3
# neighbours ['Art1', 'Art8', 'Art9']
# features ['Southeast_Asia', 'geographic region', 'Ernest Bower', 'countries', 'earthquakes', 'geography', 'Center_for_Strategic_and_International_Studies', 'think tank', 'studies']
# Article: Art4
# neighbours []
# features ['tsunamis']
# Article: Art5
# neighbours []
# features ['disaster']
# Article: Art6
# neighbours ['Art0', 'Art8']
# features ['disappearance', 'government', 'Malaysia_Airlines_Flight_370', 'aviation accident', 'attention', 'glare', '370']
# Article: Art7
# neighbours []
# features ['grades']
# Article: Art8
# neighbours ['Art3', 'Art9', 'Art6']
# features ['countries', 'government', 'Bower', 'stress test', 'agencies', 'communication', 'CNN', 'United States cable news', 'Jake_Tapper', 'human', 'coordination']
# Article: Art9
# neighbours ['Art3', 'Art8', 'Art12', 'Art11', 'Art12', 'Art11']
# features ['countries', 'critics', 'China', 'Criticism', 'journalism genre', 'complaints', 'search', 'plane', 'relatives', 'passengers', 'Vietnam']
# Article: Art10
# neighbours []
# features ['officials', 'Malaysian', 'statements', 'confusion', 'investigation', 'aspects']
# Article: Art11
# neighbours ['Art0', 'Art2', 'Art9', 'Art12', 'Art9', 'Art12']
# features ['Malaysia', 'sovereign state', 'search', 'plane', 'Beijing', 'capital', 'people', 'board', 'majority', 'displeasure', 'evidence', 'Chinese', 'location', 'Indian_Ocean', 'ocean', 'South_China_Sea', 'sea']
# Article: Art12
# neighbours ['Art9', 'Art9', 'Art11', 'Art11']
# features ['China', 'search', 'South_China_Sea', 'sea', 'information', 'Xinhua_News_Agency', 'news agency', 'fruit', 'commentary']
# Article: Art13
# neighbours []
# features ['survivors']
# (5, 2.142857142857143)

# %%
mar2.shape
# Out:
# (15, 512)

# %%
mar.shape
# Out:
# TensorShape([15, 512])

# %%
def find_best_use_conv(k, mar, ques, show=True):
    v0 =  ques#embed(abstract)
    norms = []
    for i in range(mar.shape[0]):
        norms.append([np.dot(v0,mar[i]), i])
    norms.sort(reverse=True)
    if show:
        print('top ',k, ' related nodes' )
    #print(norms[0][1])
    nodename = keys[norms[0][1]]
    for i in range(k):
        node = keys[norms[i][1]]
        if show:
            print(node)
            print(sentences[norms[i][1]])
    return norms[0:k]

# %%
for i in range(Num_of_Qs):
    ques_num = i
    ques = Ques_Embeddings[Para_Num][ques_num]
    ques_text = data_qs[Para_Num][ques_num]
    print("Ques:", ques_text)
    Num_of_Ans = len(Answer_Para[i])
    Answers_Got = [x[1] for x in find_best_use_conv(Num_of_Ans, mar2, ques)]
    Correct_Answers = Answer_Para[i]
    print("Got:",Answers_Got)
    print("Correct",Correct_Answers)
# Out:
# Ques: What are two example of natural disasters that Malaysia does not experience?
# top  3  related nodes
# Art7
# Buell shooting in Flint.
# Art0
# Animated history of the US.
# Art10
#  It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.
# Got: [7, 0, 10]
# Correct [2, 3, 4]
# Ques: Why are Chinese and Vietnamese officials critical of the Malaysian response?
# top  4  related nodes
# Art10
#  It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.
# Art12
#  But why do people deal with drugs?
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Art6
# This is the key message of this part of the animation, which is again being ignored by its critics.
# Got: [10, 12, 1, 6]
# Correct [9, 10, 11, 13]
# Ques: What has the new information from Malaysia potentially wasted time for?
# top  2  related nodes
# Art7
# Buell shooting in Flint.
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Got: [7, 1]
# Correct [12, 13]
# Ques: What neighboring countries of Malaysia have recently suffered natural disasters?
# top  2  related nodes
# Art7
# Buell shooting in Flint.
# Art3
# Did the 19th century NRA in the southern states promote gun rights for black people?
# Got: [7, 3]
# Correct [0, 1]
# Ques: Contradictory statements by the government of Malaysia have irritated what country involved with the investigation?
# top  2  related nodes
# Art10
#  It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.
# Art7
# Buell shooting in Flint.
# Got: [10, 7]
# Correct [10, 11]
# Ques: According to the media, has the Malaysian government done well in responding to the disappearance of Flight 370?
# top  3  related nodes
# Art7
# Buell shooting in Flint.
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Art5
# But if they didn't, one of their functions was to continue the racism of the KKK.
# Got: [7, 1, 5]
# Correct [6, 7, 8]
# Ques: Who was critical of Malaysia's response?
# top  2  related nodes
# Art10
#  It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.
# Art6
# This is the key message of this part of the animation, which is again being ignored by its critics.
# Got: [10, 6]
# Correct [9, 3]
# Ques: Why might Malaysia not suffer the kinds of natural disasters experienced in Indonesia and the Philippines?
# top  4  related nodes
# Art12
#  But why do people deal with drugs?
# Art7
# Buell shooting in Flint.
# Art5
# But if they didn't, one of their functions was to continue the racism of the KKK.
# Art13
#  Because it's so much fun to do so?
# Got: [12, 7, 5, 13]
# Correct [0, 1, 3, 4]
# Ques: What natural disasters does Malaysia not have?
# top  2  related nodes
# Art7
# Buell shooting in Flint.
# Art0
# Animated history of the US.
# Got: [7, 0]
# Correct [3, 4]
# Ques: Of what nationality were the majority of people aboard Malaysia Airlines Flight 370?
# top  2  related nodes
# Art3
# Did the 19th century NRA in the southern states promote gun rights for black people?
# Art5
# But if they didn't, one of their functions was to continue the racism of the KKK.
# Got: [3, 5]
# Correct [11, 6]
# Ques: What kind of grades has Malaysia received concerning its handling of the disappearance of Malaysia Airlines Flight 370?
# top  2  related nodes
# Art7
# Buell shooting in Flint.
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Got: [7, 1]
# Correct [6, 7]
# Ques: Why is it thought that the intensive search in the South China Sea was worthless?
# top  2  related nodes
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Art12
#  But why do people deal with drugs?
# Got: [1, 12]
# Correct [11, 12]

# %%
ques_num = 1

# %%
ques = Ques_Embeddings[Para_Num][ques_num]
ques_text = data_qs[Para_Num][ques_num]
print("Ques:", ques_text)
find_best_use_conv(2, mar2, ques)
# Out:
# Ques: Which key message(s) do(es) this passage say the critics ignored?
# top  2  related nodes
# Art6
# This is the key message of this part of the animation, which is again being ignored by its critics.
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# [[0.4423114547493445, 6], [0.27653367034648313, 1]]

# %%
ques = Ques_Embeddings[Para_Num][ques_num]
ques_text = data_qs[Para_Num][ques_num]
print("Ques:", ques_text)
find_best_use(4, ques)
# Out:
# Ques: Which type of rights are being discussed and promoted by which group?
# top  4  related nodes
# Art3
# Did the 19th century NRA in the southern states promote gun rights for black people?
# Art2
# But it makes a valid claim which you ignore entirely: That the strategy to promote "gun rights" for white people and to outlaw gun possession by black people was a way to uphold racism without letting an openly terrorist organization like the KKK flourish.
# Art5
# But if they didn't, one of their functions was to continue the racism of the KKK.
# Art12
#  But why do people deal with drugs?
# [[0.22711581, 3], [0.16377448, 2], [0.05284371, 5], [0.042329676, 12]]

# %% [markdown]
# ### Trying with another Convolution

# %%
def computeMar3(G, mar, lambd):
    num_zero_neighbors = 0
    tot_neighbors = 0
    num_arts = 0
    for art in G.nodes():
        if G.nodes[art]['flavor'] == 'article':
            num_arts += 1.0
            neighbors, features =  findNeighbors(G, art)
            v = np.zeros(mar.shape[1])
            c = 0.0
            if len(neighbors) == 0:
                num_zero_neighbors +=1
            tot_neighbors += len(neighbors)
            if len(neighbors) > 0:
                for x in neighbors:
                    loc = find_in_keys(x)
                    v = v + mar[loc]
                    c = c+1.0
                v = v/c
                z = lambd*mar[find_in_keys(art)] + (1.0-lambd)*v
                z = z/np.linalg.norm(z)
                mar3[find_in_keys(art)] = z
            else:
                mar3[find_in_keys(art)] = mar[find_in_keys(art)]

    return num_zero_neighbors, tot_neighbors/num_arts

# %%
mar3 = np.zeros((mar.shape[0], mar.shape[1]))
computeMar3(G, mar2,0.8)
# Out:
# (5, 2.142857142857143)

# %%
computeMar3(G, mar3,0.8)
# Out:
# (5, 2.142857142857143)

# %%
mar3
# Out:
# array([[-0.00987825, -0.13185186,  0.01273129, ...,  0.02436218,
#          0.01254944,  0.04655562],
#        [-0.07411403, -0.0440148 ,  0.00106488, ...,  0.00775546,
#          0.03265558,  0.0269998 ],
#        [-0.01465142, -0.12776715, -0.09209476, ...,  0.05102053,
#          0.03977982,  0.00957798],
#        ...,
#        [ 0.0278475 , -0.05635135, -0.00856109, ..., -0.00090087,
#          0.02650938, -0.00112581],
#        [ 0.03838673, -0.01887815,  0.03731984, ..., -0.04768466,
#         -0.02261458, -0.0073561 ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
mar2
# Out:
# array([[-0.01154379, -0.12491008,  0.02185292, ...,  0.02442696,
#          0.0080754 ,  0.04504379],
#        [-0.07427887, -0.04443317,  0.02893816, ..., -0.00425209,
#          0.03544415,  0.02841026],
#        [-0.01633071, -0.11440796, -0.10502658, ...,  0.0545803 ,
#          0.04150568,  0.00397853],
#        ...,
#        [ 0.03255021, -0.0536986 , -0.01214659, ..., -0.00149955,
#          0.02997044, -0.00174961],
#        [ 0.03838673, -0.01887815,  0.03731984, ..., -0.04768466,
#         -0.02261458, -0.0073561 ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
mar
# Out:
# <tf.Tensor: shape=(15, 512), dtype=float32, numpy=
# array([[-0.01274004, -0.11565759,  0.03097722, ...,  0.02448403,
#          0.00251936,  0.04266088],
#        [-0.06971727, -0.04264623,  0.05854981, ..., -0.01652756,
#          0.03496636,  0.0289634 ],
#        [-0.01743965, -0.09696124, -0.11560833, ...,  0.05650649,
#          0.04247527, -0.00178425],
#        ...,
#        [ 0.03638124, -0.05021678, -0.01674846, ..., -0.00129548,
#          0.03262155, -0.00195663],
#        [ 0.03838673, -0.01887815,  0.03731984, ..., -0.04768466,
#         -0.02261458, -0.0073561 ],
#        [ 0.02464328, -0.02262432,  0.03899401, ..., -0.04800109,
#          0.06842233, -0.0242082 ]], dtype=float32)>

# %%
for i in range(Num_of_Qs):
    ques_num = i
    ques = Ques_Embeddings[Para_Num][ques_num]
    ques_text = data_qs[Para_Num][ques_num]
    print("Ques:", ques_text)
    Num_of_Ans = len(Answer_Para[i])
    Answers_Got = [x[1] for x in find_best_use_conv(Num_of_Ans, mar3, ques)]
    Correct_Answers = Answer_Para[i]
    print("Got:",Answers_Got)
    print("Correct",Correct_Answers)
# Out:
# Ques: What are two example of natural disasters that Malaysia does not experience?
# top  3  related nodes
# Art7
# Buell shooting in Flint.
# Art10
#  It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.
# Art0
# Animated history of the US.
# Got: [7, 10, 0]
# Correct [2, 3, 4]
# Ques: Why are Chinese and Vietnamese officials critical of the Malaysian response?
# top  4  related nodes
# Art10
#  It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.
# Art12
#  But why do people deal with drugs?
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Art3
# Did the 19th century NRA in the southern states promote gun rights for black people?
# Got: [10, 12, 1, 3]
# Correct [9, 10, 11, 13]
# Ques: What has the new information from Malaysia potentially wasted time for?
# top  2  related nodes
# Art7
# Buell shooting in Flint.
# Art5
# But if they didn't, one of their functions was to continue the racism of the KKK.
# Got: [7, 5]
# Correct [12, 13]
# Ques: What neighboring countries of Malaysia have recently suffered natural disasters?
# top  2  related nodes
# Art7
# Buell shooting in Flint.
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Got: [7, 1]
# Correct [0, 1]
# Ques: Contradictory statements by the government of Malaysia have irritated what country involved with the investigation?
# top  2  related nodes
# Art10
#  It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.
# Art2
# But it makes a valid claim which you ignore entirely: That the strategy to promote "gun rights" for white people and to outlaw gun possession by black people was a way to uphold racism without letting an openly terrorist organization like the KKK flourish.
# Got: [10, 2]
# Correct [10, 11]
# Ques: According to the media, has the Malaysian government done well in responding to the disappearance of Flight 370?
# top  3  related nodes
# Art7
# Buell shooting in Flint.
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Art5
# But if they didn't, one of their functions was to continue the racism of the KKK.
# Got: [7, 1, 5]
# Correct [6, 7, 8]
# Ques: Who was critical of Malaysia's response?
# top  2  related nodes
# Art10
#  It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Got: [10, 1]
# Correct [9, 3]
# Ques: Why might Malaysia not suffer the kinds of natural disasters experienced in Indonesia and the Philippines?
# top  4  related nodes
# Art12
#  But why do people deal with drugs?
# Art7
# Buell shooting in Flint.
# Art5
# But if they didn't, one of their functions was to continue the racism of the KKK.
# Art13
#  Because it's so much fun to do so?
# Got: [12, 7, 5, 13]
# Correct [0, 1, 3, 4]
# Ques: What natural disasters does Malaysia not have?
# top  2  related nodes
# Art7
# Buell shooting in Flint.
# Art5
# But if they didn't, one of their functions was to continue the racism of the KKK.
# Got: [7, 5]
# Correct [3, 4]
# Ques: Of what nationality were the majority of people aboard Malaysia Airlines Flight 370?
# top  2  related nodes
# Art5
# But if they didn't, one of their functions was to continue the racism of the KKK.
# Art7
# Buell shooting in Flint.
# Got: [5, 7]
# Correct [11, 6]
# Ques: What kind of grades has Malaysia received concerning its handling of the disappearance of Malaysia Airlines Flight 370?
# top  2  related nodes
# Art7
# Buell shooting in Flint.
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Got: [7, 1]
# Correct [6, 7]
# Ques: Why is it thought that the intensive search in the South China Sea was worthless?
# top  2  related nodes
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Art12
#  But why do people deal with drugs?
# Got: [1, 12]
# Correct [11, 12]

# %%
ques = Ques_Embeddings[Para_Num][ques_num]
ques_text = data_qs[Para_Num][ques_num]
print("Ques:", ques_text)
find_best_use_conv(4, mar3, ques)
# Out:
# Ques: Which key message(s) do(es) this passage say the critics ignored?
# top  4  related nodes
# Art6
# This is the key message of this part of the animation, which is again being ignored by its critics.
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Art9
#  This characterization of a six-year-old as a pencil-stabbing thug is exactly the kind of hysteria that Moore's film warns against.
# Art10
#  It is the typical right-wing reaction which looks for simple answers that do not contradict the Republican mindset.
# [[0.42678120503680117, 6],
#  [0.3230297759431939, 1],
#  [0.1325247527957737, 9],
#  [0.12494186948493897, 10]]

# %%
ques = Ques_Embeddings[Para_Num][ques_num]
ques_text = data_qs[Para_Num][ques_num]
print("Ques:", ques_text)
find_best_use(4, ques)
# Out:
# Ques: Which key message(s) do(es) this passage say the critics ignored?
# top  4  related nodes
# Art6
# This is the key message of this part of the animation, which is again being ignored by its critics.
# Art1
# Of course the cartoon is highly oversimplified, and most critics consider it one of the weakest parts of the film.
# Art9
#  This characterization of a six-year-old as a pencil-stabbing thug is exactly the kind of hysteria that Moore's film warns against.
# Art2
# But it makes a valid claim which you ignore entirely: That the strategy to promote "gun rights" for white people and to outlaw gun possession by black people was a way to uphold racism without letting an openly terrorist organization like the KKK flourish.
# [[0.44961473, 6], [0.1999479, 1], [0.13252476, 9], [0.12503603, 2]]

# %% [markdown]
# find_best2_5 is the same as find_best2 but we eliminate all candidates that are not connected to the top choice.   This is like find_best3 above, and k must be less than 40.

# %%
def find_best2_5(k, text, show = True):
    _, norms = find_best2(40, text, show = False)
    nodename = keys[norms[0][1]]
    newlist = []
    nopath = 0
    for i in range(40):
        #print(norms[i])
        x = norms[i][1]
        try:
            path = nx.shortest_path(G, nodename, 'Art'+str(x))
            #print(path)
            newlist.append(norms[i])
        except:
            nopath += 1
    norms = newlist
    ln = len(norms)

    if show:
        print('top ',k, ' related nodes' )
    scor = 0.0
    #print(norms[0][1])
    nodename = keys[norms[0][1]]
    category =  G.nodes[nodename]['source']
    for i in range(min(k,ln)):
        node = keys[norms[i][1]]
        if scorekey(G.nodes[node]['source'],category) == 1:
            scor +=1.0
        if show:
            print(node)
            print(sentences[norms[i][1]])
            
    scor = scor/min(ln, k)
    return scor, min(ln,k)

# %% [markdown]
# ## Examples

# %%
find_best2(4, 'Black Holes are hidden by an Event horizon.')

# %%
find_best(4, 'What is dark energy?')

# %%
find_best2(4, 'What is dark energy?')

# %%
find_best(4, 'unification of general relativity and quantum theory is  supersymmetry known as supergravity')

# %%
find_best2(4, 'unification of general relativity and quantum theory is  supersymmetry known as supergravity')

# %%
find_best(4, 'What is M-theory and what does it have to do with string theory and supersymmetry theory')

# %%
find_best2(4, 'What is M-theory and what does it have to do with string theory and supersymmetry theory')

# %%
find_best(4, 'Can a neutron star and a black hole merge')

# %%
find_best2(4, 'Can a neutron star and a black hole merge')

# %%
find_best(4, 'How old is the universe and how much of the universe is dark matter and how much is dark energy')

# %%
find_best2(4, 'How old is the universe and how much of the universe is dark matter and how much is dark energy')

# %%
find_best(4, 'what is dark energy?')

# %%
find_best2(4, 'what is dark energy?')

# %%
find_best(4,'mass extinctions were caused by volcanic action and astroid impact.')

# %%
find_best2(4,'mass extinctions were caused by volcanic action and astroid impact.')

# %%
find_best(4,'What are the names of the extinction events and what is the most recent.')

# %%
find_best2(4,'What are the names of the extinction events and what is the most recent.')

# %%
find_best(4, 'is there a sixth mass extinction?')

# %%
find_best2(4, 'is there a sixth mass extinction?')

# %%
find_best(4,'The major cause of climate change is increased'+
          ' carbon dioxide levels.')

# %%
find_best2(4,'The major cause of climate change is increased'+
          ' carbon dioxide levels.')

# %%
find_best(4, 'Which extinction events were caused by asteroid impacts?')

# %%
find_best2(4, 'Which extinction events were caused by asteroid impacts?')

# %%
find_best(4, 'light neutron star')

# %%
find_best2(4, 'light neutron star')

# %%
find_best(4, 'event horizon?')

# %%
find_best2(4, 'event horizon?')

# %%
find_best(4, "who has solved Einstein's field equations?")

# %%
find_best2(4, "who has solved Einstein's field equations?")

# %% [markdown]
# ## Measuring the "accuracy" of the find_best function
# below we make three measurements of the accuracy by doing
# find_best(x) for every article in the graph.
#
# recall that the score is not a measure of accuracy, but a measure of how similar the 2nd, 3rd and 4th reply is to the 1st.
#
# find_alone give a score of 70 percent accurate.
# find_alone2 is better at 75%
#
# testing the methods that eliminate answers that are not in the same graph connected component gives even better answers, but it measures the score based on the number it found which may be less than 4. So if it finds no other answers in the component then it gets a score of 1.
#
# find_alone3 is a score of 80% and the average numer of items found is 3.24
# find_alone2_5 is a score of 83% and the averege number of items found is 3.33

# %%
artlist = []
for n in G.nodes():
    if G.nodes[n]['flavor'] == 'article':
        artlist.append(n)

# %%
numarts = len(artlist)
print(numarts)
scor = 0
for n in artlist:
    doc = G.nodes[n]['context']
    s, _ = find_best(4, doc, show=False)
    scor += s
print(scor/numarts)

# %%
numarts = len(artlist)
print(numarts)
scor = 0
num_retured = 0
for n in artlist:
    doc = G.nodes[n]['context']
    #print(doc)
    #s, _ = find_best(4, doc[0], show=False)
    s,  x = find_best3(4, doc, show=False)
    scor += s
    num_retured += x
print(scor/numarts, num_retured/numarts)

# %%
numarts = len(artlist)
print(numarts)
scor = 0
for n in artlist:
    doc = G.nodes[n]['context']
    s, _ = find_best2(4, doc, show=False)
    scor += s
print(scor/numarts)

# %%
numarts = len(artlist)
print(numarts)
scor = 0
num_returned = 0
for n in artlist:
    doc = G.nodes[n]['context']
    s, x = find_best2_5(4, doc, show=False)
    scor += s
    num_returned +=x
print(scor/numarts, num_returned/numarts)

# %% [markdown]
# ## more layers of convolution
# computerMar3 applies another layer of convolution

# %%
def computeMar3(G, mar, lambd):
    num_zero_neighbors = 0
    tot_neighbors = 0
    num_arts = 0
    for art in G.nodes():
        if G.nodes[art]['flavor'] == 'article':
            num_arts += 1.0
            neighbors, features =  findNeighbors(G, art)
            v = np.zeros((768))
            c = 0.0
            if len(neighbors) == 0:
                num_zero_neighbors +=1
            tot_neighbors += len(neighbors)
            if len(neighbors) > 0:
                for x in neighbors:
                    loc = find_in_keys(x)
                    v = v + mar[loc]
                    c = c+1.0
                v = v/c
                z = lambd*mar[find_in_keys(art)] + (1.0-lambd)*v
                z = z/np.linalg.norm(z)
                mar3[find_in_keys(art)] = z
            else:
                mar3[find_in_keys(art)] = mar[find_in_keys(art)]

    return num_zero_neighbors, tot_neighbors/num_arts

# %%
mar3 = np.zeros((len(sentences), 768))
computeMar3(G, mar2,0.8)
mar2 = mar3
numarts = len(artlist)
print(numarts)
scor = 0
for n in artlist:
    s, _ = find_best2(4, n, show=False)
    scor += s
print(scor/numarts)

# %%
mar3 = np.zeros((len(sentences), 768))
computeMar3(G, mar2,0.8)
mar2 = mar3
numarts = len(artlist)
print(numarts)
scor = 0
for n in artlist:
    s, _ = find_best_wl2(4, n, show=False)
    scor += s
print(scor/numarts)

# %%
mar3 = np.zeros((len(sentences), 768))
computeMar3(G, mar2,0.8)
mar2 = mar3
numarts = len(artlist)
print(numarts)
scor = 0
for n in artlist:
    s, _ = find_best_wl2(4, n, show=False)
    scor += s
print(scor/numarts)

# %% [markdown]
# ### Plotting the subgraph of nodes associated with a query.
# this is interesting to see.   it is also interesting to look at the "story" that
# is described by following a path through the subgraph.

# %%
def remove_trailing_and(text):
    i = text.find('and')
    if i >0:
        i = text.rindex('and')
        if len(text)-i < 7:
            return text[0:i]
        else:
            return text
    else:
        return text
    
def explain(sg, entity):
    n = sg.nodes[entity]
    inst = n['instanceof']
    instancefound = False
    sent =  entity 
    #print('=======================================')
    if n['description'] != '':
        preline = entity+'is defined as ', n['description']
    else: 
        preline = ''
    if inst != []:
        instancefound = True
        sent = sent +' is a '
        cnt = 0
        for ins in inst:
            endline = ''
            if cnt < len(inst)-1:
                endline = ' and '
                cnt = cnt+1
            if (ins[1].find('organism') < 0) and (ins[1].find('first-order') < 0) :
                sent = sent+ ins[1]+ endline
            else:
                cnt = cnt-1
    sent =  remove_trailing_and(sent)      
    inst = n['subclassof']
    if inst != []:
        if instancefound == True:
            sent = sent + ' and '
        else:
            sent = sent # + ' is '
        #sent = sent + ' a subclass of '
        #for ins in inst:
        #    sent = sent+ ins[1]+' and '
   
    print(preline, remove_trailing_and(sent))

# %%
def makeArtSubGraph(G, artlist, do_closure = True):
    oe = G.edges
    sgl = artlist
    # compute links from articles to entities
    sgl2 = []
    for x in oe:
        if x[0] in set(sgl):
            sgl2.append(x[1])
    sgl = sgl + sgl2
    sgl = set(sgl)
    sgl = list(sgl)
    #add links from entities and articles to other things
    sgl2 = []
    for x in oe:
        if x[1] in set(sgl):
            sgl2.append(x[0])
    sgl = sgl + sgl2
    sgl = set(sgl)
    sgl = list(sgl)
    
    if do_closure:
        sgl2 = []
        for x in oe:
            if x[0] in set(sgl):
                sgl2.append(x[1])
        sgl = sgl + sgl2
        sgl = set(sgl)
        sgl = list(sgl)

    sglab = {}
    for x in sgl:
        sglab[x] = x
    sg = nx.subgraph(G, sgl)
    return sglab, sg

# %%
def buildMatchingGraph(G, text , do_closure = True):
    _, s = find_best2(5, text, show=False)
    print('s=',s)
    artlist = [keys[it[1]] for it in s]
    print(len(artlist))
    for state in artlist:
        print(state+'--', G.nodes[state]['context'])
    _, sg = makeArtSubGraph(G, artlist, do_closure)
    showGraph(sg)
    print("related entities are:")
    print('=====================================')
    for nd in sg:
        n = sg.nodes[nd]
        if n['flavor']== 'entity':
            explain(sg, nd)
            print(" ")
    return sg

# %%
def explainPath(cop, X, Y):
    path = nx.shortest_path(cop, X, Y)
    print(path)
    for a in path:
        print("----------------")
        if cop.nodes[a]['flavor'] == "entity":
            print(a, cop.nodes[a]['description'])
        if cop.nodes[a]['flavor'] == 'article':
            print(a, cop.nodes[a]['context'])

# %%
sg = buildMatchingGraph(G,'best-known cause of a mass extinction is an Asteroid '+
                        'impact that killed off the Dinosaurs.')

# %%
explainPath(sg,  'supernova explosions', 'Art407')

# %%
explainPath(sg,  'Art273', 'Yucatán_Peninsula')

# %%
sg =buildMatchingGraph(G,"What is dark energy?", do_closure=False)

# %% [markdown]
# let's compute the average number of neighbors a node has.

# %%
numarts = len(artlist)
print(numarts)
scor = 0
neighbors = np.zeros(5)
for n in artlist:
    nbrs, _ = findNeighbors(G, n)
    l = len(nbrs)
    if l > 4:
        l = 4
    neighbors[l]+=1
print(neighbors)

# %%
tot = 0
for i in range(5):
    tot += neighbors[i]*i
tot/numarts

# %% [markdown]
# compute neighbors of neighbors

# %%
numarts = len(artlist)
print(numarts)
scor = 0
neighbors = np.zeros(5)
for n in artlist:
    nbrs, _ = findNeighbors(G, n)
    dubnbrs = []
    for x in nbrs:
        if x != n:
            dub, _ = findNeighbors(G, x)
            dubnbrs = dubnbrs + dub
    sdubnbrs = set(dubnbrs)
    nbrs = list(sdubnbrs)
    l = len(nbrs)
    if l > 4:
        l = 4
    neighbors[l]+=1
print(neighbors)

# %%
tot = 0
for i in range(5):
    tot += neighbors[i]*i
tot/numarts

# %%
140/427

# %% [markdown]
# one third of the nodes have no neighbors.  These nodes are not effected by the convolution operation.
#
# now  look at the sizes of the connected components.

# %%
comp = nx.connected_components(G)

# %%
num_comp = 0
comp_size = np.zeros(7)
for x in comp:
    x_size =  0
    for n in x:
        if G.node[n]['flavor'] == 'article':
            x_size += 1
    if x_size > 6:
        comp_size[6] = x_size
    else:
        comp_size[x_size] += 1
print(comp_size)

# %%
total_nodes = 0
for i in range(6):
    total_nodes += comp_size[i]*i
total_nodes + 304

# %%
tot = (76+10*2 +3*3 +4*(2+2+304))/427

# %%
tot
